# %% [markdown]
# #### SVM
# In normal SVM we had a data which we were able to devide with the help of line. What if we have data in such a way that it can not be seperated by a line. The data is not linear separably.

# %%
from IPython.display import Image
Image(filename= "dataplot.png")

# %% [markdown]
# #### Mapping to a higher dimension:

# %%
from IPython.display import Image
Image(filename= "higherdim.png")

# %% [markdown]
# #### What it basically does is take data to higher dimension and then apply the support vector machine.

# %% [markdown]
# ### Mapping to a higher dimensional space can be highly computive-intensive.

# %% [markdown]
# ### So we would be using the KERNAL trick.

# %%
from IPython.display import Image
Image(filename= "kernell.png")
